# %%
# build_feature_corpus

# %cd /content/drive/MyDrive/sanskrit_translation_data
# !pip install -e .

from src.sanskrit_translation.features import build_feature_corpus
df_features = build_feature_corpus()
df_features.head()
