# %%
# Compare all translation approaches.

# %cd /content/drive/MyDrive/sanskrit_translation_data
# !pip install -e .
# !pip install sacrebleu

from src.sanskrit_translation.evaluation import bleu_score

# prepare references, hypotheses for each model
print("Rule-based BLEU:", bleu_score(refs, hyps_rule))
print("NN BLEU:", bleu_score(refs, hyps_nn))
print("Seq2Seq BLEU:", bleu_score(refs, hyps_seq2seq))
print("Transformer BLEU:", bleu_score(refs, hyps_transformer))
