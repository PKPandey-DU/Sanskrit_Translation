# %%
# Use HuggingFace sentence-transformers or multilingual model.

# !pip install -U sentence-transformers

from sentence_transformers import SentenceTransformer
from src.sanskrit_translation.io_utils import read_csv
from src.sanskrit_translation.paths import CORPUS_CLEANED
import numpy as np
import pickle
from pathlib import Path

df = read_csv(CORPUS_CLEANED)
model = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
embeddings = model.encode(df["cleaned"].tolist(), show_progress_bar=True)

embeddings = np.array(embeddings)
Path("data").mkdir(exist_ok=True)
with open("data/sentence_embeddings.pkl", "wb") as f:
    pickle.dump(embeddings, f)
embeddings.shape
