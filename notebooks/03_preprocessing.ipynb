# %% [markdown]
# <a href="https://colab.research.google.com/github/PKPandey-DU/Sanskrit_Translation/blob/main/notebooks/03_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colab setup + !pip install indic-nlp-library
# Import preprocessing.add_tokens_and_roman
# Create corpus_preprocessed.csv

# %cd /content/drive/MyDrive/sanskrit_translation_data
# !pip install -e .
# !pip install indic-nlp-library

from src.sanskrit_translation.paths import CORPUS_CLEANED, CORPUS_PREPROCESSED
from src.sanskrit_translation.io_utils import read_csv, write_csv
from src.sanskrit_translation.preprocessing import add_tokens_and_roman

df = read_csv(CORPUS_CLEANED)
df = add_tokens_and_roman(df, col="cleaned")
write_csv(df, CORPUS_PREPROCESSED)
df.head()
