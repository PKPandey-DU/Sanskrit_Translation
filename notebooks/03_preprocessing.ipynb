# %% [markdown]
# <a href="https://colab.research.google.com/github/PKPandey-DU/Sanskrit_Translation/blob/main/notebooks/03_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install NLP Packages
# !pip install indic-nlp-library regex

# Download Indic NLP resources
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_library.git
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git

# Use Preprocessing Utilities
from indicnlp.tokenize import indic_tokenize

sample = "धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः"
tokens = indic_tokenize.trivial_tokenize(sample)
tokens

# Transliteration
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator

UnicodeIndicTransliterator.transliterate(sample, "hi", "en")

# Save Preprocessed Corpus
df["tokens"] = df["cleaned"].apply(lambda x: indic_tokenize.trivial_tokenize(x))
df["roman"] = df["cleaned"].apply(lambda x: UnicodeIndicTransliterator.transliterate(x, "hi", "en"))

df.to_csv(os.path.join(data_dir, "corpus_preprocessed.csv"), index=False)
