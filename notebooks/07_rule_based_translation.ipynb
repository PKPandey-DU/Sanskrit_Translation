# %%
# Demonstrate simple rule-based translation.

# %cd /content/drive/MyDrive/sanskrit_translation_data
# !pip install -e .
# !pip install indic-nlp-library

from src.sanskrit_translation.preprocessing import tokenize_sentence
from src.sanskrit_translation.rule_based import translate_tokens

text = "धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः"
tokens = tokenize_sentence(text)
print(tokens)
print(translate_tokens(tokens))
